# %%
import datasource
import pandas as pd

data:list[tuple] = datasource.lastest_datetime_data()
dataFrame = pd.DataFrame(data)

'''
for items in data:
    for item in items:
        print(item)
    print("=========")
'''
dataFrame
# Out:
#                              0                    1       2              3  \
# 0           YouBike2.0_捷運科技大樓站  2023-11-10 10:59:06     大安區    復興南路二段235號前
# 1       YouBike2.0_復興南路二段273號前  2023-11-10 10:59:06     大安區   復興南路二段273號西側
# 2         YouBike2.0_國北教大實小東側門  2023-11-10 10:59:06     大安區    和平東路二段96巷7號
# 3            YouBike2.0_和平公園東側  2023-11-10 10:59:06     大安區  和平東路二段118巷33號
# 4         YouBike2.0_辛亥復興路口西北側  2023-11-10 10:59:06     大安區     復興南路二段368號
# ...                        ...                  ...     ...            ...
# 1316      YouBike2.0_臺大總圖書館西南側  2023-11-10 10:59:16  臺大公館校區       臺大圖書館西南側
# 1317        YouBike2.0_臺大黑森林西側  2023-11-10 10:59:16  臺大公館校區        臺大霖澤館南側
# 1318        YouBike2.0_臺大獸醫館南側  2023-11-10 10:59:16  臺大公館校區       臺大獸醫系館南側
# 1319      YouBike2.0_臺大新體育館東南側  2023-11-10 10:59:16  臺大公館校區        臺大體育館東側
# 1320  YouBike2.0_臺大明達館北側(員工宿舍)  2023-11-10 10:59:16  臺大公館校區       明達館北側前空地
#
#        4   5   6
# 0     28   3  25
# 1     21   0  21
# ...
